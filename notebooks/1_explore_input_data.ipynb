# %% [markdown]
# # 01 – Explore Input Healthcare Query Data
#
# This notebook explores the sample input data used in the healthcare counseling
# evaluation pipeline.
#
# It will:
# - Load `data/sample_inputs/healthcare_queries_sample.csv`
# - Show basic structure and example rows
# - Summarize categories and sources
#
# No LLM responses are generated or displayed here.

# %%
import pandas as pd
from pathlib import Path

data_path = Path("data/sample_inputs/healthcare_queries_sample.csv")
df = pd.read_csv(data_path)

df.head()

# %%
df.info()

# %%
df["category"].value_counts()

# %%
df["source"].value_counts()
